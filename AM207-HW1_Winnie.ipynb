# %% [markdown]
# ## Homework1

# %% [markdown]
# ## Problem 1
# ### Part A(1):
#
# Should your child test positive, what is the probability that he/she has Type I diabetes?

# %% [markdown]
# P(Test Positive|Does not have Diabetes) = 0.01

# %% [markdown]
# P(Test False|Has Diabetes) = 0.00

# %% [markdown]
# P (Has Diabetes) = 0.00228

# %% [markdown]
# P(Has Diabetes | Test Positive)
# = P(Test Positive | Has Diabetes) P(Has Diabetes)/

# %% [markdown]
# ((P(Has Diabetes)*P(Test Positive| Has Diabetes) + P(Does not have diabetes) *P(Test Positive | Does not have diabetes))

# %%
(1-0)*0.00228 / ((0.00228*1)+(1-0.00228)*0.01)
# Out:
# 0.18601311881995888

# %% [markdown]
# **Answer:** The probability that he/she has diabetes is 0.186, which is quite low and deserves further testing for confirmation.

# %% [markdown]
# ### Part A(2):
# Later, you read online that Type I diabetes is 6 times more prevalent in prematurely born children. If this statistic is true, what is the probability that your child, who is prematurely born, has Type I diabetes?

# %% [markdown]
# The prevalence rate has changed to this: P(Has Diabetes | First Born) = 0.00228*6 = 0.01368

# %% [markdown]
# The calculation for the P(Has Diabetes | Test Positive) is still the same:

# %% [markdown]
# P(Has Diabetes | Test Positive) = P(Test Positive | Has Diabetes) P(Has Diabetes)/

# %% [markdown]
# ((P(Has Diabetes)P(Test Positive| Has Diabetes) + P(Does not have diabetes) P(Test Positive | Does not have diabetes))

# %%
(1-0)*0.01368 / ((0.01368*1)+(1-0.01368)*0.01)
# Out:
# 0.5810594991335077

# %% [markdown]
# **Answer:** Given the child is first-born, the probability that he/she has diabetes if tested positive is 0.581. I would probably not request further testing in this scenario and believe that he/she actually has diabetes.

# %% [markdown]
# ### Part B:
#
# Based on this evidence, what is the probability that Class A has the harsher grading system?

# %% [markdown]
# P(Lower Grade| In Harsher Class) = 0.35

# %% [markdown]
# P(Lower Grade | Not in Harsher Class) = 0.15

# %% [markdown]
# P(In Harsher Class | Lower Grade) = P(Lower Grade | In Harsher Class) P(Harsher Class)/

# %% [markdown]
# (P(Lower Grade| In Harsher Class) P(Harsher Class)+P(Lower Grade| Not in Harsher Class) P(Not in Harsher Class))

# %%
(0.35)*0.5 / ((0.35*0.5)+(0.15*0.5))
# Out:
# 0.7

# %% [markdown]
# **Answer:** The probability that class A has the harsher grading system is 0.7. Based on the result, I would drop class A.

# %% [markdown]
# ## Problem 2: MLE

# %% [markdown]
# The pdf from the question is this:

# %% [markdown]
# $$
# f_X(\mathbf{x}) =  4\lambda_1^2 x_{1}x_{2} \mathrm{exp} \left\{-\lambda_0 (x^2_{1} + x^2_{2}) \right\}
# $$

# %% [markdown]
# To normalize the pdf, we integrate the pdf with the support of x1 and x2.

# %% [markdown]
# $$ \int_0^\infty \int_0^\infty 4\lambda_1^2 x_{1}x_{2} \mathrm{exp} \left\{-\lambda_0 (x^2_{1} + x^2_{2}) \right\}\mathrm{d}x_{1}\mathrm{d}x_{2} = 1$$

# %% [markdown]
# $$ \int_0^\infty 2\lambda_1^2 x_{1} \mathrm{exp} \left\{-\lambda_0 (x^2_{1}) \right\} \left.\mathrm{exp} \left\{-\lambda_0 (x^2_{2}) \right\}\right|_0^\infty \left(\frac{1}{-\lambda_0}\right)\mathrm{d}x_{1} =1 $$

# %% [markdown]
# $$ \left(\frac{1}{-\lambda_0}\right)\left(\frac{1}{-\lambda_0}\right)\left.\mathrm{exp} \left\{-\lambda_0 (x^2_{1}) \right\}\right|_0^\infty = 1$$

# %% [markdown]
# $$ \left(\frac{\lambda_1}{\lambda^2_0}\right) =1 $$

# %% [markdown]
# $$ \lambda_1 = \lambda^2_0                ............ eq(1)$$

# %% [markdown]
# Looking at the MLE equation:

# %% [markdown]
#  $$ L(\lambda_0, \lambda_1) = \prod_{i=0}^3 P(x_i \mid \lambda_0,\lambda_1 )$$

# %% [markdown]
# Taking the log of it:

# %% [markdown]
# $$\ell(\lambda) = ln(P(x_0 \mid \lambda))+ ln(P(x_1 \mid \lambda))+ln(P(x_2 \mid \lambda))+ln(P(x_3 \mid \lambda))$$

# %% [markdown]
# Taking the log of each pdf function: $$ln(P(x_n \mid \lambda))= ln 4 + 2 ln \lambda_1 + ln x_{n,1} + ln x_{n,2} - \lambda_0 (x^2_{n,1} + x^2_{n,2})$$

# %% [markdown]
# Applying the equation for x0,x1,x2,x3 and rearrange the terms gives us the following equation:

# %% [markdown]
# $$ \ell(\lambda) = 4ln 4 + 8 ln \lambda_1 + ln x_{0,1} + ln x_{0,2} + ln  x_{1,1} + ln  x_{1,2}+ ln  x_{2,1} + ln  x_{2,2}+ ln  x_{3,1} + ln  x_{3,2}- \lambda_0 [(x^2_{0,1} + x^2_{0,2}) + (x^2_{1,1} + x^2_{1,2})+(x^2_{2,1} + x^2_{2,2})+(x^2_{3,1} + x^2_{3,2})]$$

# %% [markdown]
# Plugging in vectors x0,x1,x2,x3 into the equation: $\mathbf{x}^{(0)} = (0.5, 2.5), \mathbf{x}^{(1)} = (3.2, 1.3), \mathbf{x}^{(2)} = (2.72, 5.84), \mathbf{x}^{(3)}= (10.047, 0.354)$

# %% [markdown]
# Let $$[(0.5^2 + 2.5^2) + (3.2^2 +1.3^2)+ (2.72^2+5.84^2) +(10.047^2 +0.354^2))] = m $$

# %%
(0.5**2 + 2.5**2) + (3.2**2 +1.3**2)+ (2.72**2+5.84**2) +(10.047**2 +0.354**2)
# Out:
# 161.00152500000002

# %% [markdown]
# Let $$ ln 0.5 + ln 2.5 + ln  3.2 + ln  1.3+ ln  2.72 + ln  5.84+ ln  10.047 + ln  0.354 = q $$

# %% [markdown]
# $$ \ell(\lambda) = 4ln 4 + 8 ln \lambda_1 + q - m  \lambda_0 $$

# %% [markdown]
# Substitute eq(1) into $$ \ell(\lambda) $$ :

# %% [markdown]
# $$ \ell(\lambda) = 4ln 4 + 16 ln \lambda_0 + q - m  \lambda_0 $$

# %% [markdown]
# Maximising it:

# %% [markdown]
# $$\frac{d\ell}{d\lambda_0} = \frac{16}{\lambda_0} - m = 0$$

# %% [markdown]
# $$ \lambda_0 = \frac{16}{m} $$

# %%
16 / 161.00152500000002
# Out:
# 0.09937794067478553

# %%
0.09937794067478553**2
# Out:
# 0.009875975092761193

# %% [markdown]
# ** Answer ** The estimated MLE parameters are as followed: $$ \lambda_0 = 0.0994 ,\lambda_1 = 0.00988 $$

# %% [markdown]
# ### Part(B)
# Visualize the data along with the distribution you determined in part A (in two dimensions or three).

# %% [markdown]
# $$
# f_X(\mathbf{x}) =  4\lambda_1^2 x_{1}x_{2} \mathrm{exp} \left\{-\lambda_0 (x^2_{1} + x^2_{2}) \right\}
# $$

# %% [markdown]
# I will visualize the distributioin in a 3-D plot

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data, setting x and y at increments of 0.1 starting at 0
f = lambda x,y: 4*(0.009875975092761193**2)*x*y*np.exp(-0.09937794067478553*(x**2+y**2))
xpts=np.arange(0,14,0.1)
ypts=np.arange(0,14,0.1)
xpts, ypts = np.meshgrid(xpts, ypts)
# generate the values on z-axis
zpts=f(xpts,ypts)

# Plot the surface.
surf = ax.plot_surface(xpts, ypts, zpts,
                       linewidth=0, antialiased=False)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Problem 3: Frequentist Stats

# %% [markdown]
# ### Part A(1)
# I would visualize the data in a contour plot

# %%
# %matplotlib notebook
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt

path = r"C:\Users\Dell\Documents\Python Scripts\HW1_Q3.txt\HW1_Q3.txt"
trial = np.loadtxt(path, delimiter=",")
x = trial[:,0]
y = trial[:,1]
sns.jointplot(x=x, y=y, kind="kde")
# Out:
# <img src="data:image/png;base64,...">
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### Part A(2)
# I will bin the data first to obtain the probability of each bin before plotting on the contour map.

# %%
# %matplotlib notebook
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


# Binning the data by setting up 10 bins on each axis 
nbins = 10
H, xedges, yedges = np.histogram2d(x,y,bins=nbins)
X, Y = np.meshgrid(xedges[0:10], yedges[0:10])

# H needs to be rotated and flipped0
H = np.rot90(H)
H = np.flipud(H)
#Converting the counts into probability 
H = H/10000

#Plotting the contour map
plt.figure()
CS = plt.contour(X, Y, H,colors='r')
plt.clabel(CS, inline=100, fontsize=10, colors='b')
plt.title('Contours of equal probability')

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### PartA(3)
# I will subset the data that satisfied the x1 conditions before plotting the pdf

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
from numpy.random import normal,rand
import seaborn as sns

#transform the dataset into pd
df = pd.DataFrame(trial)
df.columns = ['x1','x2']

#subsetting the data based on the given condition 
df2 = df[(df['x1'] >= 3.99) & (df['x1'] <= 4.01)]

#isolating that subset
trial2 = df2['x2']

#plotting the pdf for the given subset
marginal = plt.hist(trial2, normed=True)
sns.kdeplot(trial2)
plt.title('Conditional Probability Given x1 = [3.99,4.01]')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### PartA(4)
# We will identify the marginal probability by extracting all the x1 values

# %%
# %matplotlib notebook
#subsetting the raw data with only x1 values 
trial3 = df['x1']

#plotting the pdf for the given subset
plt.hist(trial3, normed=True)
sns.kdeplot(trial3)
plt.title('Marginal Probability of x1')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### Part (B): Estimation
# - Empirically estimate the mean of the distribution $f_{x_1}$. Estimate, also the SE (standard error) of the estimate.

# %% [markdown]
# I will run a nonparametric bootstrapping to empirically estimate the mean

# %%
# %matplotlib notebook
##running a nonparametric resampling to estimate the mean empirically
M_samples=10000
N_points = trial3.shape[0]
bs_np = np.random.choice(trial3, size=(M_samples, N_points), replace=True)
sd_mean=np.mean(bs_np, axis=1)
sd_std=np.std(bs_np, axis=1)
plt.hist(sd_mean, bins=30, normed=True, alpha=0.5,label="samples");
plt.axvline(trial3.mean(), 0, 1, color='r', label='Original Data')
plt.legend()

plt.show()
#calculating the estimated mean
print("The estimated mean of x1: ", np.mean(sd_mean))

#calculating the standard error, which is S.D. of the mean over square root of sample size
import math
print("The standard error of mean is:",np.std(sd_mean)/math.sqrt(10000))
# Out:
# <img src="data:image/png;base64,...">
# The estimated mean of x1:  3.99276468691
# The standard error of mean is: 7.00090434968e-05

# %% [markdown]
# - Empirically estimate the standard deviation of the distribution $f_{x_2 \mid x_1}$, for $x_1 \in [3.99, 4.01]$. Estimate, also the SE (standard error) of the estimate.

# %% [markdown]
# I will run also a nonparametric bootstrapping to empirically estimate the S.D. of $ f_(x_2|x_1) $

# %%
# %matplotlib notebook
#running a nonparametric resampling to estimate the mean empirically
M_samples=10000
N_points = trial2.shape[0]
bs_np = np.random.choice(trial2, size=(M_samples, N_points), replace=True)
sd_mean=np.mean(bs_np, axis=1)
sd_std=np.std(bs_np, axis=1)
plt.hist(sd_mean, bins=30, normed=True, alpha=0.5,label="samples");
plt.axvline(trial2.mean(), 0, 1, color='r', label='Original Data')
plt.legend()
plt.show()


#calculate the S.D. from bootstrapping 
print("The estimated S.D. of x2|x1: ", np.mean(sd_std))
ideal = np.mean(sd_std)

#calculate the S.E. of S.D. from bootstrapping
se_ideal = (np.std(sd_std)/math.sqrt(10000))

print("The S.E. of S.D. is",se_ideal)
# Out:
# <img src="data:image/png;base64,...">
# The estimated S.D. of x2|x1:  0.734253443888
# The S.E. of S.D. is 0.000388295256655

# %% [markdown]
# Given the SE, How many significant digits in your standard deviation estimate are significant? Explain why.

# %% [markdown]
# For constructing significant intervals, it is calculated by 1.96 times(Standard Error). In this case, it is 0.000388*1.96 = 0.000762, which means that for a move that is smaller than 0.001, it would still be insignificant to our S.D. estimate. So there are 3 significant digits in the S.D. estimates.
